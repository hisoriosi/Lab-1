# %% [markdown]
# <a href="https://colab.research.google.com/github/hisoriosi/Lab-1/blob/uploud-fileGB/lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Пример сипользования Markdown**
#
# Нужно сделать:
#
#
# 1.   Спиcок
# 2.   Рисунок
# 3.   Таблицу
# 4.   Ссылку
#
# ![image.png](data:image/png;base64,...)
#
# |A|B|C|
# |:---|:---|:---|
# |11|22|33|
# |1000|250|-50|
#
# [Ссылка на руководство по Markdown](https://colab.research.google.com/notebooks/markdown_guide.ipynb)
